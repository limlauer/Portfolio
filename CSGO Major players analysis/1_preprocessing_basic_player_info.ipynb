# %% [markdown]
# **LUIS IMLAUER | 2023 | limlauer.github.io**
# # CS:GO Major players analysis
#
# **WHO IS THE CS:GO GOAT?**
# Majors are the biggest tournaments in CS:GO, and with the launch of CS2, we saw the last one forever. It's time to collect the data and analyze everything we can and answer some questions.
#
# ## WHAT WE WILL EXPLORE
# 1. Who played the most majors?
# 2. Who played the most matches
# 3. Who played the most rounds
# 4. Who has the most kills
# 5. Who has the least kills
# 6. Who has the most deaths
# 7. Who are the majors MVPs and what role did they have
# 8. What country has the players with most majors
# 9. How did the 'online era' affect players and teams
# 10. How did the Ukraine war affect players
# 11. Winners of every major
# 12. Who has the most majors
# 13. Who performed better accross all majors (In total and in average)
# 14. Who is the CS:GO GOAT?
#
#
# **IMPORTANT**
# - Older majors were given less importance (and thus less points were awarded)
# - To this date there is no hltv.org API available, so all information was gathered manually
#
# **SOURCES**
# - hltv.org
# - https://www.kaggle.com/datasets/matheusnbrega/players-stats-all-csgo-majors
#
# **LET'S START**
# - I will be doing preprocessing and data gathering in python, and creating visualizations in Tableau.

# %%
import pandas as pd
pd.options.display.max_columns = 20
pd.options.display.max_rows = 2500

# %%
df = pd.read_csv('major-stats.csv', sep=';') # This file is separated by ;
df.head()
# Out:
#        name nationality         team  maps  rounds  KD-diff    KD  rating  \
# 0     ZywOo      France     Vitality    10     277       92  1.60    1.39
# 1        iM     Romania  GamerLegion    12     306       68  1.34    1.35
# 2     Spinx      Israel     Vitality    10     277       50  1.30    1.24
# 3       NAF      Canada       Liquid     9     245       32  1.22    1.24
# 4  YEKINDAR      Latvia       Liquid     9     245       30  1.19    1.20
#
#                        event
# 0  BLAST.tv Paris Major 2023
# 1  BLAST.tv Paris Major 2023
# 2  BLAST.tv Paris Major 2023
# 3  BLAST.tv Paris Major 2023
# 4  BLAST.tv Paris Major 2023

# %%
df['name'].value_counts().unique
# Out:
# <bound method Series.unique of name
# dupreeh            23
# apEX               22
# shox               21
# karrigan           21
# rain               19
# Xyp9x              19
# olofmeister        18
# kennyS             17
# NBK-               17
# device             17
# KRIMZ              17
# Zeus               16
# nitr0              16
# EliGE              16
# flusha             15
# FalleN             15
# GuardiaN           15
# NiKo               15
# gla1ve             15
# JW                 14
# NEO                14
# GeT_RiGhT          14
# f0rest             14
# s1mple             14
# Edward             14
# fer                14
# cajunb             13
# NAF                13
# AdreN              13
# pashaBiceps        13
# Magisk             13
# byali              13
# Snax               13
# flamie             13
# kioShiMa           12
# markeloff          12
# TaZ                12
# Twistzz            12
# chrisJ             12
# dennis             12
# seized             12
# ropz               12
# aizy               12
# RpK                11
# tarik              11
# Skadoodle          11
# Dosia              11
# Qikert             11
# SmithZz            11
# Happy              11
# electroNic         11
# Jame               11
# nex                11
# TACO               11
# Xizt               11
# coldzera           10
# chopper            10
# tabseN             10
# ZywOo              10
# REZ                10
# ANGE1              10
# n0thing            10
# WorldEdit          10
# jkaem              10
# jks                10
# buster              9
# MSL                 9
# Hiko                9
# ScreaM              9
# denis               9
# B1ad3               9
# friberg             9
# HObbit              9
# AZR                 9
# cadiaN              9
# Snappi              8
# Kjaerbye            8
# Stewie2K            8
# pronax              8
# stanislaw           8
# bondik              8
# k0nfig              8
# allu                8
# Ex6TenZ             8
# Aleksib             8
# bodyy               8
# seang@res           8
# Spiidi              7
# boltz               7
# dycha               7
# shroud              7
# arT                 7
# jdm64               7
# dexter              7
# JACKZ               7
# Boombl4             7
# YEKINDAR            7
# autimatic           7
# yuurih              7
# KSCERATO            7
# RUSH                7
# gob b               7
# Spinx               7
# huNter-             7
# Lekr0               7
# frozen              7
# FL1T                7
# mou                 6
# broky               6
# ShahZaM             6
# jR                  6
# VINI                6
# CeRq                6
# roeJ                6
# Brehze              6
# wayLander           6
# hutji               6
# sdy                 6
# Lucky               6
# tiziaN              6
# woxic               6
# STYKO               6
# nicoodoz            6
# Pimp                6
# Liazz               6
# DavCost             5
# oskar               5
# felps               5
# TeSeS               5
# hades               5
# steel               5
# Sico                5
# sjuush              5
# fox                 5
# oSee                5
# Perfecto            5
# acoR                5
# twist               5
# juanflatroo         5
# hazed               5
# jabbi               5
# XANTARES            5
# gxx-                5
# kUcheR              5
# degster             5
# Maniac              5
# reltuC              5
# stavn               5
# SENER1              5
# Brollan             5
# valde               5
# starix              5
# HooXi               5
# mir                 5
# Krad                5
# saffee              5
# Maikelele           5
# somebody            5
# sinnopsyy           5
# rigoN               5
# Maden               5
# drop                5
# SEMPHIS             5
# Ethan               4
# Forester            4
# suNny               4
# gade                4
# INS                 4
# Attacker            4
# Summer              4
# Zyphon              4
# m0NESY              4
# b1t                 4
# fnx                 4
# Calyx               4
# ALEX                4
# AMANEK              4
# sh1ro               4
# SPUNJ               4
# syrsoN              4
# adreN               4
# Keoz                4
# refrezh             4
# interz              4
# Havoc               4
# ISSAA               4
# BnTeT               4
# nexa                4
# FugLy               4
# kRYSTAL             4
# nafany              4
# magixx              4
# swag                4
# Ax1Le               4
# dephh               4
# tonyblack           4
# aliStair            4
# SunPayus            4
# AZK                 4
# FeTiSh              4
# Kvik                4
# rallen              4
# Rickeh              4
# RUBINO              4
# DeadFox             4
# isak                3
# xseveN              3
# FNS                 3
# sergej              3
# Techno              3
# Golden              3
# siuhy               3
# malta               3
# zews                3
# SicK                3
# loWel               3
# xccurate            3
# iM                  3
# freakazoid          3
# Gratisfaction       3
# bLitz               3
# crush               3
# KrizzeN             3
# JUGi                3
# Aerial              3
# fitch               3
# daps                3
# waterfaLLZ          3
# znajder             3
# keshandr            3
# paz                 3
# Fifflaren           3
# mezii               3
# MAJ3R               3
# misutaaa            3
# xertioN             3
# LEGIJA              3
# torzsi              3
# Grim                3
# chelo               3
# GMX                 3
# topguN              3
# innocent            3
# Krimbo              3
# s1ren               3
# k1to                3
# hampus              3
# n0rb3r7             3
# Patsi               3
# JDC                 3
# Uzzziii             3
# DaZeD               3
# FASHR               3
# USTILO              3
# KQLY                3
# jmqa                3
# Jerry               3
# TENZKI              3
# smF                 3
# balblna             3
# Nifty               2
# nawwk               2
# zehN                2
# yay                 2
# SnypeR              2
# Zellsis             2
# Dimaoneshot         2
# Woro2k              2
# Shara               2
# SIXER               2
# hooch               2
# S0tF1k              2
# ANDROID             2
# Furlan              2
# GruBy               2
# BOROS               2
# headtr1ck           2
# DD                  2
# peet                2
# NertZ               2
# ngiN                2
# kaze                2
# Polly               2
# DEVIL               2
# keev                2
# pita                2
# mixwell             2
# COLDYY1             2
# Hyper               2
# captainMo           2
# Troubley            2
# smooya              2
# EspiranTo           2
# DemQQ               2
# Bymas               2
# floppy              2
# Sf                  2
# Nico                2
# JT                  2
# Hatz                2
# niko                2
# El1an               2
# doto                2
# jL                  2
# MICHU               2
# Lack1               2
# F1KU                2
# NickelBack          2
# oBo                 2
# WOOD7               2
# Plopski             2
# fame                2
# LOMME               2
# HaRts               2
# Devilwalk           2
# neaLaN              2
# dav1deuS            2
# sk0R                2
# latto               2
# s1n                 2
# kabal               2
# dumau               2
# es3tag              2
# EXR                 2
# max                 2
# raalz               2
# anger               2
# dgt                 2
# SANJI               2
# kyxsan              2
# flameZ              2
# kNgV-               2
# kinqie              2
# speed4k             2
# hardzao             2
# LETN1               2
# svyat               2
# zorte               2
# LUCAS1              2
# zevy                2
# erkaSt              2
# shalfey             2
# kRaSnaL             2
# biguzera            2
# Freeman             2
# Lucaozy             2
# DickStacy           2
# ottoNd              2
# NEKIZ               2
# Friis               2
# Annihilation        2
# Vexite              2
# FaNg                2
# ableJ               2
# NEOFRAG             2
# xelos               1
# MODDII              1
# abE                 1
# ceh9                1
# COLON               1
# James               1
# yam                 1
# ioRek               1
# SKYTTEN             1
# ultra               1
# centeks             1
# Delpan              1
# emagine             1
# RiX                 1
# cype                1
# zqkS                1
# stavros             1
# dumz                1
# HUNDEN              1
# blackpoisoN         1
# MINISE              1
# strux1              1
# fel1x               1
# stonde              1
# disturbed           1
# natu                1
# mouz                1
# AcilioN             1
# SZPERO              1
# zende               1
# BENDJI              1
# desi                1
# alexRr              1
# r0bs3n              1
# racno               1
# Detrony             1
# zEVES               1
# prb                 1
# Skurk               1
# MithilF             1
# ub1que              1
# berg                1
# astaRR              1
# RiTz                1
# Ace                 1
# fxy0                1
# deviaNt             1
# KHRN                1
# ptr                 1
# cent                1
# xartE               1
# jasonR              1
# nukkye              1
# Professor_Chaos     1
# Luken               1
# KENSI               1
# Tuurtle             1
# xfl0ud              1
# exit                1
# nin9                1
# Norwi               1
# imoRR               1
# Farlig              1
# rox                 1
# blameF              1
# junior              1
# Kyojin              1
# LNZ                 1
# DANK1NG             1
# SLOWLY              1
# b4rtiN              1
# jnt                 1
# DeathZz             1
# JOTA                1
# Thomas              1
# arya                1
# Bart4k              1
# mynio               1
# KEi                 1
# skullz              1
# vsm                 1
# history             1
# r3salt              1
# hallzerk            1
# hasteka             1
# w0nderful           1
# faveN               1
# Kylar               1
# Staehr              1
# lauNX               1
# slaxz-              1
# try                 1
# nqz                 1
# buda                1
# HexT                1
# PKL                 1
# mopoz               1
# alex                1
# HEN1                1
# CYPHER              1
# hardstyle           1
# devoduvek           1
# dimasick            1
# LOVEYY              1
# xms                 1
# Karsa               1
# maLeK               1
# HS                  1
# pancc               1
# Zero                1
# disco doplan        1
# pyth                1
# spaze               1
# zonic               1
# koosta              1
# DAVEY               1
# THREAT              1
# snatchie            1
# vice                1
# CRUC1AL             1
# draken              1
# dav1g               1
# realz1n             1
# Goofy               1
# xsepower            1
# facecrack           1
# Ramz1kBO$$          1
# almazer             1
# t0rick              1
# volt                1
# npl                 1
# yel                 1
# xand                1
# DeStiNy             1
# aumaN               1
# zhokiNg             1
# sterling            1
# advent              1
# robiin              1
# Name: count, dtype: int64>

# %%
df[df['name'] == 'dupreeh']
# Out:
#          name nationality        team  maps  rounds  KD-diff    KD  rating  \
# 19    dupreeh     Denmark    Vitality    10     277       11  1.07    1.11
# 189   dupreeh     Denmark    Vitality     5     166        1  1.01    1.05
# 285   dupreeh     Denmark    Vitality     8     211      -11  0.92    0.98
# 377   dupreeh     Denmark    Vitality    10     277      -30  0.84    0.95
# 438   dupreeh     Denmark    Vitality     5     122        6  1.08    1.02
# 521   dupreeh     Denmark    Astralis     6     151       -7  0.93    0.99
# 580   dupreeh     Denmark    Astralis     8     201       23  1.18    1.10
# 659   dupreeh     Denmark    Astralis    13     382       37  1.16    1.10
# 805   dupreeh     Denmark    Astralis    11     265       43  1.27    1.24
# 965   dupreeh     Denmark    Astralis    10     252       41  1.28    1.24
# 1041  dupreeh     Denmark    Astralis     4     122       48  1.76    1.47
# 1155  dupreeh     Denmark    Astralis     4      94       -7  0.90    1.02
# 1286  dupreeh     Denmark    Astralis     9     240       22  1.13    1.20
# 1388  dupreeh     Denmark    Astralis    13     349        7  1.03    1.08
# 1483  dupreeh     Denmark    Astralis     2      50       -7  0.82    0.99
# 1529  dupreeh     Denmark    Astralis     6     149       20  1.22    1.20
# 1607  dupreeh     Denmark         TSM     4      94       13  1.20    1.18
# 1704  dupreeh     Denmark         TSM     7     169       22  1.22    1.08
# 1779  dupreeh     Denmark         TSM     6     152        7  1.07    1.03
# 1867  dupreeh     Denmark    Dignitas     4      96        8  1.12    1.04
# 1936  dupreeh     Denmark    Dignitas     7     178       21  1.17    1.13
# 2025  dupreeh     Denmark    Dignitas     6     141       11  1.12    1.04
# 2105  dupreeh     Denmark  CPH Wolves     5     121        6  1.07    1.04
#
#                                            event
# 19                     BLAST.tv Paris Major 2023
# 189                           IEM Rio Major 2022
# 285         IEM Rio Major 2022 Challengers Stage
# 377                       PGL Major Antwerp 2022
# 438     PGL Major Antwerp 2022 Challengers Stage
# 521                     PGL Major Stockholm 2021
# 580   PGL Major Stockholm 2021 Challengers Stage
# 659                 StarLadder Major Berlin 2019
# 805                            IEM Katowice 2019
# 965                            FACEIT Major 2018
# 1041         FACEIT Major 2018 Challengers Stage
# 1155                          ELEAGUE Major 2018
# 1286                       PGL Major Krakow 2017
# 1388                          ELEAGUE Major 2017
# 1483                        ESL One Cologne 2016
# 1529                           MLG Columbus 2016
# 1607             DreamHack Open Cluj-Napoca 2015
# 1704                        ESL One Cologne 2015
# 1779                       ESL One Katowice 2015
# 1867                       DreamHack Winter 2014
# 1936                        ESL One Cologne 2014
# 2025                       EMS One Katowice 2014
# 2105                       DreamHack Winter 2013

# %%
# I know dupreeh attended every major, but there were 19 of them, not 23
df[df['name'] == 'dupreeh']['name'].count()
# As we can see above, there is information about the "Challengers Stage"
# We don't need that, so we will just drop those rows
# Out:
# 23

# %%
df = df[~df['event'].str.contains('Challengers Stage')]
df[df['name'] == 'dupreeh']['name'].count()
# Out:
# 19

# %%
df['event'].unique()
# Out:
# array(['BLAST.tv Paris Major 2023', 'IEM Rio Major 2022',
#        'PGL Major Antwerp 2022', 'PGL Major Stockholm 2021',
#        'StarLadder Major Berlin 2019', 'IEM Katowice 2019',
#        'FACEIT Major 2018', 'ELEAGUE Major 2018', 'PGL Major Krakow 2017',
#        'ELEAGUE Major 2017', 'ESL One Cologne 2016', 'MLG Columbus 2016',
#        'DreamHack Open Cluj-Napoca 2015', 'ESL One Cologne 2015',
#        'ESL One Katowice 2015', 'DreamHack Winter 2014',
#        'ESL One Cologne 2014', 'EMS One Katowice 2014',
#        'DreamHack Winter 2013'], dtype=object)

# %% [markdown]
# ### 1 - Who played the most majors?

# %%
# Perfect, now we have the general statistics for every player at every event.

print("Majors played")
for name, count in df['name'].value_counts().head(10).items():
    print(f"{name:13}>> {count} majors")
# Out:
# Majors played
# dupreeh      >> 19 majors
# apEX         >> 17 majors
# shox         >> 17 majors
# karrigan     >> 17 majors
# device       >> 16 majors
# Xyp9x        >> 16 majors
# olofmeister  >> 16 majors
# rain         >> 16 majors
# KRIMZ        >> 15 majors
# Zeus         >> 15 majors

# %% [markdown]
# ### 2 - Who played the most matches?

# %%
print("Total matches played")
df.groupby('name')['maps'].sum().sort_values(ascending=False).head(10)
# Out:
# Total matches played
# name
# dupreeh        138
# olofmeister    126
# device         123
# Xyp9x          118
# KRIMZ          115
# karrigan       114
# rain           112
# apEX           111
# s1mple         110
# Zeus           109
# Name: maps, dtype: int64

# %% [markdown]
# ### 3 - Who played the most rounds?

# %%
print("Total rounds played")
df.groupby('name')['rounds'].sum().sort_values(ascending=False).head(10)
# Out:
# Total rounds played
# name
# dupreeh        3603
# olofmeister    3322
# device         3184
# karrigan       3099
# Xyp9x          3044
# rain           3036
# KRIMZ          2997
# apEX           2975
# s1mple         2899
# Zeus           2791
# Name: rounds, dtype: int64

# %% [markdown]
# ## Adding more data

# %%
# We need more info that isn't included in the dataset. Let's do some scraping (no API yet for HLTV.org)
# First let's find the id for the players, the events, the URL format for each player in each event, and get the info from those pages.

# Dupreeh's link: https://www.hltv.org/player/7398/dupreeh
# https://www.hltv.org/stats/players/events/7398/dupreeh - all events played by dupreeh
# https://www.hltv.org/stats/players/individual/7398/dupreeh?event=6972 - individual stats at "BLAST Premier Spring Final 2023" (6972)

# %%
# Adding the event ID to each row
event_ids_dict = {
    'BLAST.tv Paris Major 2023': 6973, # https://www.hltv.org/events/6793/blasttv-paris-major-2023 For some reason, this is 6972 for dupreeh
    'IEM Rio Major 2022': 6586, # https://www.hltv.org/events/6586/iem-rio-major-2022
    'PGL Major Antwerp 2022': 6372, # https://www.hltv.org/events/6372/pgl-major-antwerp-2022
    'PGL Major Stockholm 2021': 4866, # https://www.hltv.org/events/4866/pgl-major-stockholm-2021
    'StarLadder Major Berlin 2019': 4443, # https://www.hltv.org/events/4443/starladder-major-berlin-2019
    'IEM Katowice 2019': 3883, # https://www.hltv.org/events/3883/iem-katowice-2019
    'FACEIT Major 2018': 3564, # https://www.hltv.org/events/3564/faceit-major-2018
    'ELEAGUE Major 2018': 3247, # https://www.hltv.org/events/3247/eleague-major-2018
    'PGL Major Krakow 2017': 2720, # https://www.hltv.org/events/2720/pgl-major-krakow-2017
    'ELEAGUE Major 2017': 2471, # https://www.hltv.org/events/2471/eleague-major-2017
    'ESL One Cologne 2016': 2062, # https://www.hltv.org/events/2062/esl-one-cologne-2016
    'MLG Columbus 2016': 2027, # https://www.hltv.org/events/2027/mlg-columbus-2016
    'DreamHack Open Cluj-Napoca 2015': 1617, # https://www.hltv.org/events/1617/dreamhack-open-cluj-napoca-2015
    'ESL One Cologne 2015': 1666, # https://www.hltv.org/events/1666/esl-one-cologne-2015
    'ESL One Katowice 2015': 1611, # https://www.hltv.org/events/1611/esl-one-katowice-2015
    'DreamHack Winter 2014': 1553, # https://www.hltv.org/events/1553/dreamhack-winter-2014
    'ESL One Cologne 2014': 1444, # https://www.hltv.org/events/1444/esl-one-cologne-2014
    'EMS One Katowice 2014': 1333, # https://www.hltv.org/events/1333/ems-one-katowice-2014
    'DreamHack Winter 2013': 1270 # https://www.hltv.org/events/1270/dreamhack-winter-2013
}

df['event_ID'] = df['event'].map(event_ids_dict)
df.loc[(df['name'] == 'dupreeh') & (df['event'] == 'BLAST.tv Paris Major 2023'), 'event_ID'] = 6972
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1521 entries, 0 to 2161
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1521 non-null   object
#  1   nationality  1521 non-null   object
#  2   team         1521 non-null   object
#  3   maps         1521 non-null   int64
#  4   rounds       1521 non-null   int64
#  5   KD-diff      1521 non-null   int64
#  6   KD           1521 non-null   float64
#  7   rating       1521 non-null   float64
#  8   event        1521 non-null   object
#  9   event_ID     1521 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 130.7+ KB

# %%
# Import libraries
# Had to use selenium
from selenium import webdriver
driver = webdriver.Chrome()
from bs4 import BeautifulSoup
import requests
import smtplib

# %%
# Let's test if it works first

URL = "https://www.hltv.org/stats/players/individual/7398/dupreeh?event=6972"
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver = webdriver.Chrome()
driver.get(URL)
page_source = driver.page_source
driver.quit()

soup1 = BeautifulSoup(page_source, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

stats_rows = soup2.find_all('div', class_='stats-row')
for row in stats_rows:
    stat_name = row.find('span').text.strip()
    stat_value = row.find_all('span')[1].text.strip()
    print(f"{stat_name}: {stat_value}")
# Out:
# Kills: 200
# Deaths: 233
# Kill / Death: 0.86
# Kill / Round: 0.61
# Rounds with kills: 138
# Kill - Death difference: K - D diff.
# Total opening kills: 31
# Total opening deaths: 44
# Opening kill ratio: 0.70
# Opening kill rating: 0.91
# Team win percent after first kill: 80.6%
# First kill in won rounds: 15.2%
# 0 kill rounds: 192
# 1 kill rounds: 95
# 2 kill rounds: 26
# 3 kill rounds: 15
# 4 kill rounds: 2
# 5 kill rounds: 0
# Rifle kills: 153
# Sniper kills: 1
# SMG kills: 15
# Pistol kills: 31
# Grenade: 0
# Other: 1

# %% [markdown]
# It works! We can now add all of that data to our dataset, it will take some time but we should only be doing this once for every row.

# %%
df['player_id'] = 0
df.loc[df['name'] == 'dupreeh', 'player_id'] = 7398

# %%
# Let's scrape some more and after we are finished, check if the data is complete and good to go
# There are 1521 rows in total.
# Let's start with dupreeh

player_id = 7398
player_name = 'dupreeh'
event_event_ID = 6972
URL = f"https://www.hltv.org/stats/players/individual/{player_id}/{player_name}?event={event_event_ID}"
#HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver = webdriver.Chrome()
driver.get(URL)
page_source = driver.page_source
driver.quit()

soup1 = BeautifulSoup(page_source, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

stats_rows = soup2.find_all('div', class_='stats-row')
for row in stats_rows:
    stat_name = row.find('span').text.strip()
    stat_value = row.find_all('span')[1].text.strip()
    print(f"{stat_name}: {stat_value}")
# Out:
# Kills: 200
# Deaths: 233
# Kill / Death: 0.86
# Kill / Round: 0.61
# Rounds with kills: 138
# Kill - Death difference: K - D diff.
# Total opening kills: 31
# Total opening deaths: 44
# Opening kill ratio: 0.70
# Opening kill rating: 0.91
# Team win percent after first kill: 80.6%
# First kill in won rounds: 15.2%
# 0 kill rounds: 192
# 1 kill rounds: 95
# 2 kill rounds: 26
# 3 kill rounds: 15
# 4 kill rounds: 2
# 5 kill rounds: 0
# Rifle kills: 153
# Sniper kills: 1
# SMG kills: 15
# Pistol kills: 31
# Grenade: 0
# Other: 1

# %% [markdown]
# There we printed every piece of data we can gather from that page. Let's divide that into columns and add it gradually to the df. Note that KD difference shows as K - D diff. so we should fix that before adding it to the database
#
# But first, we need to get every player id on hltv

# %%
import re

df['name'].unique().__len__()

# 391 different players, that's too much to do manually
# Let's try to automate this task using the search bar on hltv.org
# Out:
# 391

# %%
# This script below took me hours to code and test, and I should have used regex for everything (I think); but as soon as it worked I just wanted to keep going, I'll maybe fix it in the future
def extract_player_info(csv_name, Player_Names_List, Overwrite, Start_index = 0, Ending_index = 0):
    try:
        loaded_df = pd.read_csv(csv_name)
        print("Loaded existing CSV.")
    except FileNotFoundError:
        print("CSV file not found. Creating a new DataFrame.")
        loaded_df = pd.DataFrame(columns=['Name', 'Full name', 'Player ID', 'Full link', 'Multiple'])
    Output_DF = loaded_df

    if (Ending_index == 0):
        Ending_index = Player_Names_List.unique().__len__()

    print(f"Preparing to search for {Ending_index} players...")
    player_names = Player_Names_List.unique()[Start_index:Ending_index]
    multiple_results, p_fullname, p_playerid, p_fullLink = False, 'Error', 'Error', 'Error'

    names = list(Output_DF['Name'])

    for p_name in player_names:
        if (p_name in names) and (not Overwrite):
            print(f"{p_name} already searched, skipping")
        else:
            multiple_results = False
            URL = f"https://www.hltv.org/search?query={p_name.lower()}"
            driver = webdriver.Chrome()
            driver.get(URL)
            page_source = driver.page_source
            driver.quit()
            soup1 = BeautifulSoup(page_source, "html.parser")

            tables = soup1.find_all('table', class_='table')
            starting, ending = 0, 0 # starting and ending indexes
            for i, row in enumerate(str(tables).split('\n')):
                if row == '<td class="table-header">Player</td>':
                    starting = i + 3
                if row == '<td class="table-header">Article</td>':
                    ending = i - 3
            results = str(tables).split('\n')[starting:ending]
            
            if len(results) > 1:
                multiple_results = True
            
            results = results[0]
            p_fullname = (results.split('"/>')[1]).split('</a>')[0]
            p_playerid = results.split('/')[2]
            pattern = r'href="(/player/\d+/[^"]+)"'
            match = re.search(pattern, results)
            if match:
                p_fullLink = match.group(1)

            print(f"{p_name} -> {multiple_results}, {p_fullname}, {p_playerid}, https://www.hltv.org{p_fullLink}")
            
            new_player_dict = {
                'Name': p_name,
                'Full name': p_fullname, 
                'Player ID': p_playerid, 
                'Full link': 'https://www.hltv.org' + p_fullLink, 
                'Multiple': multiple_results
            }
            
            Output_DF = pd.concat([Output_DF, pd.DataFrame([new_player_dict])], ignore_index=True)

    Output_DF.to_csv("player_hltv_info.csv", index=False)
    print("File saved as player_hltv_info.csv")

# %%
extract_player_info("player_hltv_info.csv", df['name'], False, Ending_index = 25)
# Out:
# Loaded existing CSV.
# Preparing to search for 25 players...
# ZywOo already searched, skipping
# iM already searched, skipping
# Spinx already searched, skipping
# NAF already searched, skipping
# YEKINDAR already searched, skipping
# broky already searched, skipping
# stavn already searched, skipping
# NiKo already searched, skipping
# headtr1ck already searched, skipping
# ropz already searched, skipping
# cadiaN already searched, skipping
# BOROS already searched, skipping
# NertZ already searched, skipping
# Magisk already searched, skipping
# jks already searched, skipping
# gxx- already searched, skipping
# mezii already searched, skipping
# juanflatroo already searched, skipping
# oSee already searched, skipping
# dupreeh already searched, skipping
# CYPHER already searched, skipping
# m0NESY already searched, skipping
# acoR already searched, skipping
# jkaem already searched, skipping
# CRUC1AL already searched, skipping
# File saved as player_hltv_info.csv

# %% [markdown]
# It works! Now let's do it for every player (~11.5 seconds per player, it should take about 1:10 hours)

# %%
extract_player_info("player_hltv_info.csv", df['name'], False)
# Out:
# Loaded existing CSV.
# Preparing to search for 391 players...
# ZywOo already searched, skipping
# iM already searched, skipping
# Spinx already searched, skipping
# NAF already searched, skipping
# YEKINDAR already searched, skipping
# broky already searched, skipping
# stavn already searched, skipping
# NiKo already searched, skipping
# headtr1ck already searched, skipping
# ropz already searched, skipping
# cadiaN already searched, skipping
# BOROS already searched, skipping
# NertZ already searched, skipping
# Magisk already searched, skipping
# jks already searched, skipping
# gxx- already searched, skipping
# mezii already searched, skipping
# juanflatroo already searched, skipping
# oSee already searched, skipping
# dupreeh already searched, skipping
# CYPHER already searched, skipping
# m0NESY already searched, skipping
# acoR already searched, skipping
# jkaem already searched, skipping
# CRUC1AL already searched, skipping
# sdy already searched, skipping
# Brollan already searched, skipping
# Perfecto already searched, skipping
# s1mple already searched, skipping
# huNter- already searched, skipping
# nawwk already searched, skipping
# Woro2k already searched, skipping
# jabbi already searched, skipping
# apEX already searched, skipping
# nicoodoz already searched, skipping
# DemQQ already searched, skipping
# siuhy already searched, skipping
# electroNic already searched, skipping
# volt already searched, skipping
# rallen already searched, skipping
# Aleksib already searched, skipping
# REZ already searched, skipping
# isak already searched, skipping
# nitr0 already searched, skipping
# kRaSnaL already searched, skipping
# Twistzz already searched, skipping
# kyxsan already searched, skipping
# b1t already searched, skipping
# sjuush already searched, skipping
# TeSeS already searched, skipping
# rain already searched, skipping
# Goofy already searched, skipping
# KSCERATO already searched, skipping
# rigoN already searched, skipping
# roeJ already searched, skipping
# sinnopsyy already searched, skipping
# STYKO already searched, skipping
# KRIMZ already searched, skipping
# jL already searched, skipping
# EliGE already searched, skipping
# FASHR already searched, skipping
# dycha already searched, skipping
# SENER1 already searched, skipping
# Thomas already searched, skipping
# k0nfig already searched, skipping
# SunPayus already searched, skipping
# hades already searched, skipping
# arT already searched, skipping
# Keoz already searched, skipping
# Maden already searched, skipping
# karrigan already searched, skipping
# Kylar already searched, skipping
# HooXi already searched, skipping
# yuurih already searched, skipping
# Snappi already searched, skipping
# npl already searched, skipping
# mynio already searched, skipping
# saffee already searched, skipping
# KEi already searched, skipping
# drop already searched, skipping
# sh1ro already searched, skipping
# Jame already searched, skipping
# FL1T already searched, skipping
# fame already searched, skipping
# Zyphon already searched, skipping
# w0nderful already searched, skipping
# frozen already searched, skipping
# Ax1Le already searched, skipping
# Patsi already searched, skipping
# magixx already searched, skipping
# HObbit already searched, skipping
# nafany already searched, skipping
# chopper already searched, skipping
# n0rb3r7 already searched, skipping
# hampus already searched, skipping
# k1to already searched, skipping
# s1ren already searched, skipping
# Staehr already searched, skipping
# syrsoN already searched, skipping
# valde already searched, skipping
# torzsi already searched, skipping
# s1n already searched, skipping
# Krimbo already searched, skipping
# es3tag already searched, skipping
# Qikert already searched, skipping
# xertioN already searched, skipping
# JDC already searched, skipping
# dexter already searched, skipping
# interz already searched, skipping
# refrezh already searched, skipping
# lauNX already searched, skipping
# tabseN already searched, skipping
# slaxz- already searched, skipping
# fer already searched, skipping
# degster already searched, skipping
# faveN already searched, skipping
# VINI already searched, skipping
# buster already searched, skipping
# boltz already searched, skipping
# FalleN already searched, skipping
# JACKZ already searched, skipping
# Boombl4 already searched, skipping
# misutaaa already searched, skipping
# Plopski already searched, skipping
# tiziaN already searched, skipping
# fnx already searched, skipping
# shox already searched, skipping
# Bymas already searched, skipping
# nexa already searched, skipping
# El1an already searched, skipping
# AMANEK already searched, skipping
# device already searched, skipping
# olofmeister already searched, skipping
# MICHU already searched, skipping
# Brehze already searched, skipping
# Stewie2K already searched, skipping
# Forester already searched, skipping
# Lack1 already searched, skipping
# gla1ve already searched, skipping
# CeRq already searched, skipping
# Krad already searched, skipping
# Kyojin already searched, skipping
# Lucky already searched, skipping
# NickelBack already searched, skipping
# Grim already searched, skipping
# oBo already searched, skipping
# Xyp9x already searched, skipping
# LNZ already searched, skipping
# doto already searched, skipping
# stanislaw already searched, skipping
# allu already searched, skipping
# Kjaerbye already searched, skipping
# sergej already searched, skipping
# ottoNd already searched, skipping
# flamie already searched, skipping
# Liazz already searched, skipping
# tarik already searched, skipping
# gade already searched, skipping
# ALEX already searched, skipping
# woxic already searched, skipping
# aizy already searched, skipping
# EspiranTo already searched, skipping
# chrisJ already searched, skipping
# Gratisfaction already searched, skipping
# RpK already searched, skipping
# SANJI already searched, skipping
# Aerial already searched, skipping
# kennyS already searched, skipping
# AZR already searched, skipping
# xseveN already searched, skipping
# Zeus already searched, skipping
# JUGi already searched, skipping
# Ethan already searched, skipping
# Lekr0 already searched, skipping
# NEO already searched, skipping
# AdreN already searched, skipping
# GuardiaN already searched, skipping
# LUCAS1 already searched, skipping
# TACO already searched, skipping
# NBK- already searched, skipping
# svyat already searched, skipping
# LETN1 already searched, skipping
# speed4k already searched, skipping
# GeT_RiGhT already searched, skipping
# kinqie already searched, skipping
# Golden already searched, skipping
# zews already searched, skipping
# f0rest already searched, skipping
# coldzera already searched, skipping
# flusha already searched, skipping
# autimatic already searched, skipping
# nex already searched, skipping
# Edward already searched, skipping
# kioShiMa already searched, skipping
# ShahZaM already searched, skipping
# ISSAA already searched, skipping
# XANTARES already searched, skipping
# RUSH already searched, skipping
# felps already searched, skipping
# FugLy already searched, skipping
# Rickeh already searched, skipping
# n0thing already searched, skipping
# dephh already searched, skipping
# gob b already searched, skipping
# bodyy already searched, skipping
# dennis already searched, skipping
# Zellsis already searched, skipping
# KrizzeN already searched, skipping
# daps already searched, skipping
# fitch already searched, skipping
# DeadFox already searched, skipping
# ANGE1 already searched, skipping
# smooya already searched, skipping
# suNny already searched, skipping
# bondik already searched, skipping
# BnTeT already searched, skipping
# tonyblack already searched, skipping
# ANDROID already searched, skipping
# Skadoodle already searched, skipping
# yay already searched, skipping
# Kvik already searched, skipping
# jR already searched, skipping
# DD already searched, skipping
# xccurate already searched, skipping
# draken already searched, skipping
# JW already searched, skipping
# jmqa already searched, skipping
# oskar already searched, skipping
# Xizt already searched, skipping
# crush already searched, skipping
# SmithZz already searched, skipping
# balblna already searched, skipping
# waterfaLLZ already searched, skipping
# hutji already searched, skipping
# Ex6TenZ already searched, skipping
# Snax already searched, skipping
# somebody already searched, skipping
# captainMo already searched, skipping
# Dosia already searched, skipping
# paz already searched, skipping
# MAJ3R already searched, skipping
# Calyx already searched, skipping
# jdm64 already searched, skipping
# mou already searched, skipping
# MSL already searched, skipping
# LEGIJA already searched, skipping
# keev already searched, skipping
# keshandr already searched, skipping
# ngiN already searched, skipping
# mir already searched, skipping
# cajunb already searched, skipping
# byali already searched, skipping
# TaZ already searched, skipping
# pashaBiceps already searched, skipping
# kNgV- already searched, skipping
# HEN1 already searched, skipping
# zehN already searched, skipping
# denis already searched, skipping
# wayLander already searched, skipping
# steel already searched, skipping
# HS already searched, skipping
# kRYSTAL already searched, skipping
# markeloff already searched, skipping
# loWel already searched, skipping
# WorldEdit already searched, skipping
# innocent already searched, skipping
# seized already searched, skipping
# shroud already searched, skipping
# B1ad3 already searched, skipping
# fox already searched, skipping
# twist already searched, skipping
# Pimp already searched, skipping
# RUBINO already searched, skipping
# mixwell already searched, skipping
# znajder already searched, skipping
# Hiko already searched, skipping
# Happy already searched, skipping
# Zero already searched, skipping
# disco doplan already searched, skipping
# SIXER already searched, skipping
# ScreaM already searched, skipping
# pronax already searched, skipping
# Spiidi already searched, skipping
# pyth already searched, skipping
# hazed already searched, skipping
# spaze already searched, skipping
# TENZKI already searched, skipping
# pita already searched, skipping
# Shara already searched, skipping
# friberg already searched, skipping
# reltuC already searched, skipping
# hooch already searched, skipping
# zonic already searched, skipping
# koosta already searched, skipping
# DEVIL already searched, skipping
# adreN already searched, skipping
# DAVEY already searched, skipping
# Maikelele already searched, skipping
# THREAT already searched, skipping
# arya already searched, skipping
# Professor_Chaos already searched, skipping
# freakazoid already searched, skipping
# jasonR already searched, skipping
# abE already searched, skipping
# Furlan already searched, skipping
# seang@res already searched, skipping
# Hyper already searched, skipping
# GruBy already searched, skipping
# FNS already searched, skipping
# peet already searched, skipping
# DavCost already searched, skipping
# USTILO already searched, skipping
# SPUNJ already searched, skipping
# Maniac already searched, skipping
# emagine already searched, skipping
# yam already searched, skipping
# Havoc already searched, skipping
# James already searched, skipping
# SnypeR already searched, skipping
# SEMPHIS already searched, skipping
# topguN already searched, skipping
# disturbed already searched, skipping
# zEVES already searched, skipping
# kUcheR already searched, skipping
# Troubley already searched, skipping
# KHRN already searched, skipping
# ptr already searched, skipping
# Polly already searched, skipping
# xartE already searched, skipping
# starix already searched, skipping
# zqkS already searched, skipping
# stonde already searched, skipping
# natu already searched, skipping
# swag already searched, skipping
# berg already searched, skipping
# desi already searched, skipping
# BENDJI already searched, skipping
# zende already searched, skipping
# SZPERO already searched, skipping
# FeTiSh already searched, skipping
# AcilioN already searched, skipping
# mouz already searched, skipping
# AZK already searched, skipping
# fel1x already searched, skipping
# strux1 already searched, skipping
# MINISE already searched, skipping
# Friis already searched, skipping
# blackpoisoN already searched, skipping
# HUNDEN already searched, skipping
# dumz already searched, skipping
# stavros already searched, skipping
# alexRr already searched, skipping
# r0bs3n already searched, skipping
# smF already searched, skipping
# racno already searched, skipping
# Detrony already searched, skipping
# cent already searched, skipping
# deviaNt already searched, skipping
# KQLY already searched, skipping
# Nico already searched, skipping
# Sf already searched, skipping
# fxy0 already searched, skipping
# GMX already searched, skipping
# Uzzziii already searched, skipping
# Ace already searched, skipping
# Fifflaren already searched, skipping
# RiTz already searched, skipping
# DaZeD already searched, skipping
# astaRR already searched, skipping
# RiX already searched, skipping
# ub1que already searched, skipping
# MithilF already searched, skipping
# Skurk already searched, skipping
# prb already searched, skipping
# EXR already searched, skipping
# raalz already searched, skipping
# cype already searched, skipping
# anger already searched, skipping
# Devilwalk already searched, skipping
# HaRts already searched, skipping
# LOMME already searched, skipping
# COLON already searched, skipping
# SKYTTEN already searched, skipping
# Delpan already searched, skipping
# ceh9 already searched, skipping
# centeks already searched, skipping
# ultra already searched, skipping
# ioRek already searched, skipping
# xelos already searched, skipping
# MODDII already searched, skipping
# robiin already searched, skipping
# File saved as player_hltv_info.csv

# %%
try:
        loaded_df = pd.read_csv("player_hltv_info.csv")
        print("Loaded existing CSV.")
except FileNotFoundError:
    print("CSV file not found. Creating a new DataFrame.")

loaded_df.head()
# Out:
# Loaded existing CSV.
#        Name                     Full name  Player ID  \
# 0     ZywOo       Mathieu 'ZywOo' Herbaut      11893
# 1        iM  Oleksandr 's1mple' Kostyliev       7998
# 2     Spinx          Lotan 'Spinx' Giladi      18221
# 3       NAF          Keith 'NAF' Markovic       8520
# 4  YEKINDAR   Mareks 'YEKINDAR' Gaļinskis      13915
#
#                                     Full link  Multiple
# 0     https://www.hltv.org/player/11893/zywoo     False
# 1     https://www.hltv.org/player/7998/s1mple      True
# 2     https://www.hltv.org/player/18221/spinx     False
# 3        https://www.hltv.org/player/8520/naf      True
# 4  https://www.hltv.org/player/13915/yekindar     False

# %% [markdown]
# Some searches return multiple results (For example: iM returns "s1mple" as the first result), so let's see which players are imported correctly and which aren't.
#
# 1. Filter by Multiple
# 2. Check every player

# %%
percentage_true = (loaded_df[loaded_df['Multiple'] == True].shape[0] / loaded_df.shape[0]) * 100
print(f"Percentage of 'Multiple' = True: {percentage_true:.0f}%")
# Out:
# Percentage of 'Multiple' = True: 50%

# %% [markdown]
# To be honest, I expected this result. Some players will be easy to classify as correct/incorrect.
# I will do that in excel and re-import the filtered file.
#
# • IN EXCEL:
# 1. I filtered by "Multiple = True" and added the "Checked" and "Correct" column
# 2. Then, I fixed every link that was wrong. This was because player names were similar, or because some of them are now coaches.
# 3. Finally, I used a Search function to find the name of the player in the link, and see if it was referring to that player.
# 4. After I manually checked everything I saved it and we are ready to continue our analysis.

# %%
try:
        loaded_df = pd.read_csv("player_hltv_info_check.csv")
        print("Loaded existing CSV.")
except FileNotFoundError:
    print("CSV file not found. Creating a new DataFrame.")

loaded_df.head()
# Out:
# Loaded existing CSV.
#        Name                     Full name  Player ID  \
# 0     ZywOo       Mathieu 'ZywOo' Herbaut      11893
# 1        iM               Mihai 'iM' Ivan      14759
# 2     Spinx          Lotan 'Spinx' Giladi      18221
# 3       NAF          Keith 'NAF' Markovic       8520
# 4  YEKINDAR  Mareks 'YEKINDAR' GaÄ¼inskis      13915
#
#                                     Full link
# 0     https://www.hltv.org/player/11893/zywoo
# 1        https://www.hltv.org/player/14759/im
# 2     https://www.hltv.org/player/18221/spinx
# 3        https://www.hltv.org/player/8520/naf
# 4  https://www.hltv.org/player/13915/yekindar

# %% [markdown]
# There are some enconding errors, we could fix those but we can also just fix the ones we see in the final results, which I think is easier.
#
# We gathered great data, but now it's time to merge it with our original df and save everything!

# %%
merged_df = df.merge(loaded_df, left_on='name', right_on='Name', how='left')
merged_df.head()
# Out:
#        name nationality         team  maps  rounds  KD-diff    KD  rating  \
# 0     ZywOo      France     Vitality    10     277       92  1.60    1.39
# 1        iM     Romania  GamerLegion    12     306       68  1.34    1.35
# 2     Spinx      Israel     Vitality    10     277       50  1.30    1.24
# 3       NAF      Canada       Liquid     9     245       32  1.22    1.24
# 4  YEKINDAR      Latvia       Liquid     9     245       30  1.19    1.20
#
#                        event  event_ID  player_id      Name  \
# 0  BLAST.tv Paris Major 2023      6973          0     ZywOo
# 1  BLAST.tv Paris Major 2023      6973          0        iM
# 2  BLAST.tv Paris Major 2023      6973          0     Spinx
# 3  BLAST.tv Paris Major 2023      6973          0       NAF
# 4  BLAST.tv Paris Major 2023      6973          0  YEKINDAR
#
#                       Full name  Player ID  \
# 0       Mathieu 'ZywOo' Herbaut      11893
# 1               Mihai 'iM' Ivan      14759
# 2          Lotan 'Spinx' Giladi      18221
# 3          Keith 'NAF' Markovic       8520
# 4  Mareks 'YEKINDAR' GaÄ¼inskis      13915
#
#                                     Full link
# 0     https://www.hltv.org/player/11893/zywoo
# 1        https://www.hltv.org/player/14759/im
# 2     https://www.hltv.org/player/18221/spinx
# 3        https://www.hltv.org/player/8520/naf
# 4  https://www.hltv.org/player/13915/yekindar

# %%
# Let's drop the second 'Name' column
merged_df = merged_df.drop(['Name'], axis = 1)
merged_df.head()
# Out:
#        name nationality         team  maps  rounds  KD-diff    KD  rating  \
# 0     ZywOo      France     Vitality    10     277       92  1.60    1.39
# 1        iM     Romania  GamerLegion    12     306       68  1.34    1.35
# 2     Spinx      Israel     Vitality    10     277       50  1.30    1.24
# 3       NAF      Canada       Liquid     9     245       32  1.22    1.24
# 4  YEKINDAR      Latvia       Liquid     9     245       30  1.19    1.20
#
#                        event  event_ID  player_id  \
# 0  BLAST.tv Paris Major 2023      6973          0
# 1  BLAST.tv Paris Major 2023      6973          0
# 2  BLAST.tv Paris Major 2023      6973          0
# 3  BLAST.tv Paris Major 2023      6973          0
# 4  BLAST.tv Paris Major 2023      6973          0
#
#                       Full name  Player ID  \
# 0       Mathieu 'ZywOo' Herbaut      11893
# 1               Mihai 'iM' Ivan      14759
# 2          Lotan 'Spinx' Giladi      18221
# 3          Keith 'NAF' Markovic       8520
# 4  Mareks 'YEKINDAR' GaÄ¼inskis      13915
#
#                                     Full link
# 0     https://www.hltv.org/player/11893/zywoo
# 1        https://www.hltv.org/player/14759/im
# 2     https://www.hltv.org/player/18221/spinx
# 3        https://www.hltv.org/player/8520/naf
# 4  https://www.hltv.org/player/13915/yekindar

# %%
# And that 'player_id' column too
merged_df = merged_df.drop(['player_id'], axis = 1)
merged_df.head()
# Out:
#        name nationality         team  maps  rounds  KD-diff    KD  rating  \
# 0     ZywOo      France     Vitality    10     277       92  1.60    1.39
# 1        iM     Romania  GamerLegion    12     306       68  1.34    1.35
# 2     Spinx      Israel     Vitality    10     277       50  1.30    1.24
# 3       NAF      Canada       Liquid     9     245       32  1.22    1.24
# 4  YEKINDAR      Latvia       Liquid     9     245       30  1.19    1.20
#
#                        event  event_ID                     Full name  \
# 0  BLAST.tv Paris Major 2023      6973       Mathieu 'ZywOo' Herbaut
# 1  BLAST.tv Paris Major 2023      6973               Mihai 'iM' Ivan
# 2  BLAST.tv Paris Major 2023      6973          Lotan 'Spinx' Giladi
# 3  BLAST.tv Paris Major 2023      6973          Keith 'NAF' Markovic
# 4  BLAST.tv Paris Major 2023      6973  Mareks 'YEKINDAR' GaÄ¼inskis
#
#    Player ID                                   Full link
# 0      11893     https://www.hltv.org/player/11893/zywoo
# 1      14759        https://www.hltv.org/player/14759/im
# 2      18221     https://www.hltv.org/player/18221/spinx
# 3       8520        https://www.hltv.org/player/8520/naf
# 4      13915  https://www.hltv.org/player/13915/yekindar

# %% [markdown]
# Great, now let's add more information, specifically the individual stats from a player in a given event.
# (The example data is what we pulled from dupreeh in the last major)
#
# We will be adding:
# 1. OVERALL STATS
# - Kills: 200
# - Deaths: 233
# - Kill / Death: 0.86
# - Kill / Round: 0.61
# - Rounds with kills: 138
# - Kill - Death difference: K - D diff.
#
# 2. OPENING STATS
# - Total opening kills: 31
# - Total opening deaths: 44
# - Opening kill ratio: 0.70
# - Opening kill rating: 0.91
# - Team win percent after first kill: 80.6%
# - First kill in won rounds: 15.2%
#
# 3. ROUND STATS
# - 0 kill rounds: 192
# - 1 kill rounds: 95
# - 2 kill rounds: 26
# - 3 kill rounds: 15
# - 4 kill rounds: 2
# - 5 kill rounds: 0
#
# 4. WEAPON STATS
# - Rifle kills: 153
# - Sniper kills: 1
# - SMG kills: 15
# - Pistol kills: 31
# - Grenade: 0
# - Other: 1

# %%
# Continues in the next notebook!
merged_df.to_csv("basic_players_info.csv", index=False)
print("File saved as basic_players_info.csv")
# Out:
# File saved as basic_players_info.csv
